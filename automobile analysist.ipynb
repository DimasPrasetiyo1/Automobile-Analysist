# %%
# import library
import pandas as pd
import numpy as np

# %%
path = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork971-2022-01-01"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.60  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front   88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front   94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front   99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front   99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front   99.8  ...
#
#    130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
# create headers list
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
        "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
        "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
        "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = headers

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 199      sedan          rwd           front       109.1  ...          141
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          173
# 202      sedan          rwd           front       109.1  ...          145
# 203      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df1 = df.replace('?', np.nan)

# %%
df = df1.dropna(subset =['price'], axis = 0)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.to_csv("automobile.csv", index=False)

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.830000   98.848000  174.228000   65.898000   53.791500
# std      1.248557    6.038261   12.347132    2.102904    2.428449
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.675000   64.175000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.500000   66.675000   55.525000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   200.000000   200.000000         200.000000  200.000000   200.000000
# mean   2555.705000   126.860000          10.170100   25.200000    30.705000
# std     518.594552    41.650501           4.014163    6.432487     6.827227
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df[['symboling', 'length', 'width', 'height', 'horsepower', 'price']]
# Out:
#      symboling  length  width  height horsepower  price
# 0            3   168.8   64.1    48.8        111  16500
# 1            1   171.2   65.5    52.4        154  16500
# 2            2   176.6   66.2    54.3        102  13950
# 3            2   176.6   66.4    54.3        115  17450
# 4            2   177.3   66.3    53.1        110  15250
# ..         ...     ...    ...     ...        ...    ...
# 199         -1   188.8   68.9    55.5        114  16845
# 200         -1   188.8   68.8    55.5        160  19045
# 201         -1   188.8   68.9    55.5        134  21485
# 202         -1   188.8   68.9    55.5        106  22470
# 203         -1   188.8   68.9    55.5        114  22625
#
# [200 rows x 6 columns]

# %%
missing_data = df.isnull()

# %%
missing_data.head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print(" ")
# Out:
# symboling
# False    200
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      36
# Name: normalized-losses, dtype: int64
#
# make
# False    200
# Name: make, dtype: int64
#
# fuel-type
# False    200
# Name: fuel-type, dtype: int64
#
# aspiration
# False    200
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    198
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    200
# Name: body-style, dtype: int64
#
# drive-wheels
# False    200
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    200
# Name: engine-location, dtype: int64
#
# wheel-base
# False    200
# Name: wheel-base, dtype: int64
#
# length
# False    200
# Name: length, dtype: int64
#
# width
# False    200
# Name: width, dtype: int64
#
# height
# False    200
# Name: height, dtype: int64
#
# curb-weight
# False    200
# Name: curb-weight, dtype: int64
#
# engine-type
# False    200
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %% [markdown]
# Calculate Mean Value For the 'normalized-losses' and replace nan with Mean value

# %%
avg_normalized_losses = df['normalized-losses'].astype('float').mean(axis=0)
print("Average normalized-losses", avg_normalized_losses)
# Out:
# Average normalized-losses 122.0

# %%
df['normalized-losses'].replace(np.nan, avg_normalized_losses, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3584188084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['normalized-losses'].replace(np.nan, avg_normalized_losses, inplace=True)

# %% [markdown]
# Calculate Mean Value For the 'bore' and replace nan with Mean value

# %%
avg_bore = df["bore"].astype("float").mean(axis=0)
print("Average of Bore : ", avg_bore)
# Out:
# Average of Bore :  3.3300000000000005

# %%
df["bore"].replace(np.nan, avg_bore, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\1952189479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["bore"].replace(np.nan, avg_bore, inplace=True)

# %% [markdown]
# Calculate Mean Value For the 'stroke' and replace nan with Mean value

# %%
avg_stroke = df["stroke"].astype("float").mean(axis=0)
print("Average Stroke : ", avg_stroke)
# Out:
# Average Stroke :  3.2598469387755036

# %%
df["stroke"].replace(np.nan, avg_stroke, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3589830416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["stroke"].replace(np.nan, avg_stroke, inplace=True)

# %% [markdown]
# Calculate Mean Value For the 'horsepower' and replace nan with Mean value

# %%
avg_horsepower = df["horsepower"].astype("float").mean(axis=0)
print("Average HorsePower : ", avg_horsepower)
# Out:
# Average HorsePower :  103.35858585858585

# %%
df["horsepower"].replace(np.nan, avg_horsepower, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\1074039262.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horsepower"].replace(np.nan, avg_horsepower, inplace=True)

# %% [markdown]
# Calculate Mean Value For the 'peak-rpm' and replace nan with Mean value

# %%
avg_peak_rpm = df["peak-rpm"].astype("float").mean(axis=0)
print("Average peak-rpm : ", avg_peak_rpm)
# Out:
# Average peak-rpm :  5118.181818181818

# %%
df["peak-rpm"].replace(np.nan, avg_peak_rpm, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3912905256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["peak-rpm"].replace(np.nan, avg_peak_rpm, inplace=True)

# %%
df["num-of-doors"].value_counts()
# Out:
# four    113
# two      85
# Name: num-of-doors, dtype: int64

# %%
df["num-of-doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
df["num-of-doors"].value_counts().idxmin()
# Out:
# 'two'

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3             122.0  alfa-romero       gas        std
# 1            1             122.0  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2             122.0         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df["num-of-doors"].replace(np.nan, "four", inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\2789465289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["num-of-doors"].replace(np.nan, "four", inplace=True)

# %%
df.dropna(subset=["price"], axis=0, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\599160855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["price"], axis=0, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3             122.0  alfa-romero       gas        std          two
# 1          1             122.0  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2             122.0         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# mengubah tipe data kolom
df[['bore', 'stroke']] = df[['bore', 'stroke']].astype('float')
df[['price']] = df[['price']].astype('float')
df[['normalized-losses']] = df[['normalized-losses']].astype('int')
df[['peak-rpm']] =df[['peak-rpm']].astype('float')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\2885658634.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['bore', 'stroke']] = df[['bore', 'stroke']].astype('float')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\2885658634.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['price']] = df[['price']].astype('float')
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\2885658634.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two    hatchback          rwd           front        94.5  ...
# 2         four        sedan          fwd           front        99.8  ...
# 3         four        sedan          4wd           front        99.4  ...
# 4          two        sedan          fwd           front        99.8  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# Data Standardization

# %%
df['city-L/100km'] = 235/df['city-mpg']
df.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\1071948227.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city-L/100km'] = 235/df['city-mpg']
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# ...

# %%
df["highway-100km"] = 235/df['highway-mpg']
df.rename(columns={"highway-mpg" : "highway-100km"}, inplace=True)
df.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3081009435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["highway-100km"] = 235/df['highway-mpg']
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3081009435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"highway-mpg" : "highway-100km"}, inplace=True)
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# ...

# %% [markdown]
# Data Normalization

# %% [markdown]
# <p><b>Target:</b> would like to normalize those variables so their value ranges from 0 to 1</p>

# %%
df['length'] = df['length']/df['length'].max()
df['height'] = df['height']/df['height'].max()
df['width'] = df['width']/df['width'].max()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3621525286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['length'] = df['length']/df['length'].max()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3621525286.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['height'] = df['height']/df['height'].max()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\3621525286.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df[["width", "height", "length"]].head()
# Out:
#       width    height    length
# 0  0.890278  0.816054  0.811148
# 1  0.909722  0.876254  0.822681
# 2  0.919444  0.908027  0.848630
# 3  0.922222  0.908027  0.848630
# 4  0.920833  0.887960  0.851994

# %% [markdown]
# <h4><p><b>Binning<b><p><h4>

# %%
# CONVERT DATA TO CORRECT FORMAT
df['horsepower'] = df['horsepower'].astype(int, copy=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\857630268.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower'] = df['horsepower'].astype(int, copy=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df['horsepower'])

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins = np.linspace(min(df['horsepower']), max(df['horsepower']), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
df[['horsepower','horsepower-binned']].head(20)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_7240\1821571573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True )
#     horsepower horsepower-binned
# 0          111               Low
# 1          154            Medium
# 2          102               Low
# 3          115               Low
# 4          110               Low
# 5          110               Low
# 6          110               Low
# 7          140            Medium
# 8          101               Low
# 9          101               Low
# 10         121            Medium
# 11         121            Medium
# 12         121            Medium
# 13         182            Medium
# ...

# %%
df["horsepower-binned"].value_counts()
# Out:
# Low       152
# Medium     43
# High        5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
import matplotlib.pyplot as pyplot

pyplot.bar(group_names,df["horsepower-binned"].value_counts())

pyplot.xlabel("Count")
pyplot.ylabel("Horsepower")
pyplot.title("Horsepower Bins")
# Out:
# Text(0.5, 1.0, 'Horsepower Bins')

# %%
pyplot.hist(df["horsepower"], bins=3)

pyplot.xlabel("horsepower")
pyplot.ylabel("Count")
pyplot.title("Horsepower Bins")
# Out:
# Text(0.5, 1.0, 'Horsepower Bins')

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-100km', 'price', 'city-L/100km', 'highway-100km',
#        'horsepower-binned'],
#       dtype='object')

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1
# Out:
#      diesel  gas
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ..      ...  ...
# 195       0    1
# 196       0    1
# 197       0    1
# 198       1    0
# 199       0    1
#
# [200 rows x 2 columns]

# %%
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0                 0              1
# 1                 0              1
# 2                 0              1
# 3                 0              1
# 4                 0              1

# %%
# merge data frame "df" and "dummy_variable_1" 
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "fuel-type" from "df"
df.drop("fuel-type", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          1                122  alfa-romero        std          two
# 2          2                164         audi        std         four
# 3          2                164         audi        std         four
# 4          2                122         audi        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1    hatchback          rwd           front        94.5  0.822681  ...
# 2        sedan          fwd           front        99.8  0.848630  ...
# 3        sedan          4wd           front        99.4  0.848630  ...
# 4        sedan          fwd           front        99.8  0.851994  ...
#
#    horsepower  peak-rpm  city-mpg highway-100km    price  city-L/100km  \
# ...

# %%
# get indicator variables of aspiration and assign it to data frame "dummy_variable_2"
dummy_variable_2 = pd.get_dummies(df['aspiration'])

# change column names for clarity
dummy_variable_2.rename(columns={'std':'aspiration-std', 'turbo': 'aspiration-turbo'}, inplace=True)

# show first 5 instances of data frame "dummy_variable_1"
dummy_variable_2.head()
# Out:
#    aspiration-std  aspiration-turbo
# 0               1                 0
# 1               1                 0
# 2               1                 0
# 3               1                 0
# 4               1                 0

# %%
# merge the new dataframe to the original datafram
df = pd.concat([df, dummy_variable_2], axis=1)

# drop original column "aspiration" from "df"
df.drop('aspiration', axis = 1, inplace=True)

# %%
df.to_csv("clean_data.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.dtypes
# Out:
# symboling               int64
# normalized-losses       int32
# make                   object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower              int32
# peak-rpm              float64
# city-mpg                int64
# highway-100km           int64
# price                 float64
# city-L/100km          float64
# highway-100km         float64
# horsepower-binned    category
# fuel-type-diesel        uint8
# fuel-type-gas           uint8
# aspiration-std          uint8
# aspiration-turbo        uint8
# ...

# %%
df["peak-rpm"].dtypes
# Out:
# dtype('float64')

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.469772   -0.529145 -0.364511
# normalized-losses   0.469772           1.000000   -0.057068  0.019433
# wheel-base         -0.529145          -0.057068    1.000000  0.879005
# length             -0.364511           0.019433    0.879005  1.000000
# width              -0.237262           0.086961    0.814593  0.857271
# height             -0.542261          -0.377664    0.583789  0.492955
# curb-weight        -0.234743           0.099404    0.787584  0.881058
# engine-size        -0.112069           0.112362    0.576779  0.685531
# bore               -0.145667          -0.029867    0.501534  0.610817
# stroke              0.008244           0.055759    0.144675  0.120888
# compression-ratio  -0.181073          -0.114738    0.249689  0.159203
# horsepower          0.074581           0.217323    0.375732  0.580477
# ...

# %%
df[["bore", "stroke", "compression-ratio", "horsepower"]].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.051087           0.002021    0.566690
# stroke            -0.051087  1.000000           0.186761    0.100351
# compression-ratio  0.002021  0.186761           1.000000   -0.214162
# horsepower         0.566690  0.100351          -0.214162    1.000000

# %% [markdown]
# POSITIVE Linear Relationship

# %%
sns.regplot(x='engine-size', y='price', data=df)
plt.xlim(0,)
# Out:
# (0.0, 339.25)

# %%
df[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872337
# price           0.872337  1.000000

# %%
sns.regplot(x='horsepower', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
df[['horsepower', 'price']].corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.809779
# price         0.809779  1.000000

# %% [markdown]
# WEAK Linear Relationship

# %%
sns.regplot(x='peak-rpm', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %%
sns.regplot(x='stroke', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %%
df[['stroke', 'price']].corr()
# Out:
#           stroke     price
# stroke  1.000000  0.083296
# price   0.083296  1.000000

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  200.000000         200.000000  200.000000  200.000000  200.000000
# mean     0.830000         122.000000   98.848000    0.837232    0.915250
# std      1.248557          32.076542    6.038261    0.059333    0.029207
# min     -2.000000          65.000000   86.600000    0.678039    0.837500
# 25%      0.000000         100.250000   94.500000    0.800937    0.891319
# 50%      1.000000         122.000000   97.000000    0.832292    0.909722
# 75%      2.000000         138.250000  102.400000    0.881788    0.926042
# max      3.000000         256.000000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  ...  \
# count  200.000000   200.000000   200.000000  200.000000  200.000000  ...
# mean     0.899523  2555.705000   126.860000    3.330000    3.259847  ...
# std      0.040610   518.594552    41.650501    0.268562    0.314177  ...
# ...

# %%
df.describe(include=['object'])
# Out:
#           make num-of-doors body-style drive-wheels engine-location  \
# count      200          200        200          200             200
# unique      22            2          5            3               2
# top     toyota         four      sedan          fwd           front
# freq        32          115         94          118             197
#
#        engine-type num-of-cylinders fuel-system
# count          200              200         200
# unique           6                7           8
# top            ohc             four        mpfi
# freq           145              156          91

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     74
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
data_drive_wheels = df['drive-wheels'].value_counts().to_frame()
data_drive_wheels.rename(columns={'drive-wheels':'value_counts'}, inplace=True)
data_drive_wheels
# Out:
#      value_counts
# fwd           118
# rwd            74
# 4wd             8

# %%
data_drive_wheels.index.name = 'drive-wheels'
data_drive_wheels
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     74
# 4wd                      8

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location':'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts
# Out:
#                  value_counts
# engine-location
# front                     197
# rear                        3

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df_group_one = df[['drive-wheels', 'body-style', 'price']]
df_group_one
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  16500.0
# 1            rwd    hatchback  16500.0
# 2            fwd        sedan  13950.0
# 3            4wd        sedan  17450.0
# 4            fwd        sedan  15250.0
# ..           ...          ...      ...
# 195          rwd        sedan  16845.0
# 196          rwd        sedan  19045.0
# 197          rwd        sedan  21485.0
# 198          rwd        sedan  22470.0
# 199          rwd        sedan  22625.0
#
# [200 rows x 3 columns]

# %%
df_group_one = df_group_one.groupby(['drive-wheels'], as_index=False).mean(['price'])
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19842.243243

# %%
df_gtest = df[['drive-wheels', 'body-style', 'price']]
df_group_test = df_gtest.groupby(['drive-wheels', 'body-style'], as_index=False).mean()
df_group_test
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  26563.250000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
grouped_pivot = df_group_test.pivot(index='drive-wheels', columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd             11595.00   8249.000000   8396.387755   9811.800000
# rwd             26563.25  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
grouped_pivot = grouped_pivot.fillna(0)
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                 0.00      0.000000   7603.000000  12647.333333
# fwd             11595.00   8249.000000   8396.387755   9811.800000
# rwd             26563.25  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
sns.boxplot(x="body-style", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
avg_group = df[['body-style', 'price']]
avg_groupby = avg_group.groupby(['body-style'], as_index=False).mean('price')
avg_groupby
# Out:
#     body-style         price
# 0  convertible  23569.600000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
import matplotlib as plt
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
#use the grouped results
plt.pcolormesh(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.469772   -0.529145 -0.364511
# normalized-losses   0.469772           1.000000   -0.057068  0.019433
# wheel-base         -0.529145          -0.057068    1.000000  0.879005
# length             -0.364511           0.019433    0.879005  1.000000
# width              -0.237262           0.086961    0.814593  0.857271
# height             -0.542261          -0.377664    0.583789  0.492955
# curb-weight        -0.234743           0.099404    0.787584  0.881058
# engine-size        -0.112069           0.112362    0.576779  0.685531
# bore               -0.145667          -0.029867    0.501534  0.610817
# stroke              0.008244           0.055759    0.144675  0.120888
# compression-ratio  -0.181073          -0.114738    0.249689  0.159203
# horsepower          0.074581           0.217323    0.375732  0.580477
# ...

# %% [markdown]
# <b>P-value</b>
#
# <p>What is this P-value? The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when the
#
# <ul>
#     <li>p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>

# %%
from scipy import stats

# %%
person_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("Person correlation coefficient of wheel-base", person_coef, "with p-value of price",p_value)
# Out:
# Person correlation coefficient of wheel-base 0.5891470005448705 with p-value of price 4.4570195020504053e-20

# %%
person_coef, p_value = stats.pearsonr(df["horsepower"], df["price"])
print("Person correlation coefficient of wheel-base", person_coef, "with p-value of price",p_value)
# Out:
# Person correlation coefficient of wheel-base 0.8097789763551083 with p-value of price 9.887379251281569e-48

# %% [markdown]
# <h3>ANOVA: Analysis of Variance</h3>
# <p>The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:</p>
#
# <p><b>F-test score</b>: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.</p>
#
# <p><b>P-value</b>:  P-value tells how statistically significant our calculated score value is.</p>
#
# <p>If our price variable is strongly correlated with the variable we are analyzing, we expect ANOVA to return a sizeable F-test score and a small p-value.</p>

# %% [markdown]
# <h2>Data Drive<h2>

# %% [markdown]
# <p>Since ANOVA analyzes the difference between different groups of the same variable, the groupby function will come in handy. Because the ANOVA algorithm averages the data automatically, we do not need to take the average before hand.</p>
#
# <p>To see if different types of 'drive-wheels' impact  'price', we group the data.</p>

# %%
grouped_test_2 = df_gtest[["drive-wheels", "price"]].groupby(df["drive-wheels"])
grouped_test_2.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  16500.0
# 1            rwd  16500.0
# 2            fwd  13950.0
# 3            4wd  17450.0
# 4            fwd  15250.0
# 135          4wd   7603.0

# %%
df_gtest
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  16500.0
# 1            rwd    hatchback  16500.0
# 2            fwd        sedan  13950.0
# 3            4wd        sedan  17450.0
# 4            fwd        sedan  15250.0
# ..           ...          ...      ...
# 195          rwd        sedan  16845.0
# 196          rwd        sedan  19045.0
# 197          rwd        sedan  21485.0
# 198          rwd        sedan  22470.0
# 199          rwd        sedan  22625.0
#
# [200 rows x 3 columns]

# %%
grouped_test_2.get_group('4wd')['price']
# Out:
# 3      17450.0
# 135     7603.0
# 139     9233.0
# 140    11259.0
# 143     8013.0
# 144    11694.0
# 149     7898.0
# 150     8778.0
# Name: price, dtype: float64

# %%
f_val, p_value = stats.f_oneway(grouped_test_2.get_group('fwd')['price'], grouped_test_2.get_group('rwd')['price'], grouped_test_2.get_group('4wd')['price'])
print("ANOVA Result, F :", f_val, "P :", p_value)
# Out:
# ANOVA Result, F : 68.49603532807176 P : 2.6116313994533863e-23

# %%
f_val, p_val = stats.f_oneway(grouped_test_2.get_group('fwd')['price'], grouped_test_2.get_group('rwd')['price'])  
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 131.59324661179534 , P = 1.7388247444783448e-23

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
df.dtypes
# Out:
# symboling               int64
# normalized-losses       int32
# make                   object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower              int32
# peak-rpm              float64
# city-mpg                int64
# highway-100km           int64
# price                 float64
# city-L/100km          float64
# highway-100km         float64
# horsepower-binned    category
# fuel-type-diesel        uint8
# fuel-type-gas           uint8
# aspiration-std          uint8
# aspiration-turbo        uint8
# ...

# %%
X = df[['horsepower']]
Y = df['price']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat = lm.predict(X)
Yhat[0:5]
# Out:
# array([14522.49782811, 21929.00359774, 12972.2989461 , 15211.47510901,
#        14350.25350789])

# %%
lm.intercept_
# Out:
# -4596.621716732765

# %%
lm.coef_
# Out:
# array([172.24432022])

# %%
lm1 = LinearRegression()
X = df[['engine-size']]
Y = df['price']

# %%
lm.fit(df[['engine-size']], df[['price']])
# Out:
# LinearRegression()

# %%
lm.predict(X)
Yhat[0:5]
# Out:
# array([14522.49782811, 21929.00359774, 12972.2989461 , 15211.47510901,
#        14350.25350789])

# %%
lm.intercept_
# Out:
# array([-7962.44097916])

# %%
lm.coef_
# Out:
# array([[166.8621392]])

# %%
Z = df[['horsepower','engine-size', 'curb-weight', 'highway-100km']]

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# -41980.14004213709

# %%
lm.coef_
# Out:
# array([  50.86857181,   60.46169651,    4.58415948,  457.08999817,
#        2052.73835677])

# %%
lm2 = LinearRegression()
lm2.fit(df[['normalized-losses', 'highway-100km']], df["price"])
# Out:
# LinearRegression()

# %%
lm2.coef_
# Out:
# array([-1.40904933e+00,  6.97454587e+02,  5.92012423e+03])

# %%
lm2.intercept_
# Out:
# -55645.39355800144

# %%
import seaborn as sns
plt.figure(figsize=(5, 7))


ax = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# d:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# d:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.regplot(x='peak-rpm', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
lm1 = LinearRegression()
lm1
X1 = df[['city-mpg']]
Y1 = df['price']
lm1.fit(X1,Y1)
Yhat1=lm1.predict(X1)
Yhat1[0:5]
# Out:
# array([16780.38202332, 18482.61632014, 14227.03057809, 19333.73346855,
#        18482.61632014])

# %%
lm1.intercept_
# Out:
# 34653.84213990769

# %%
width =12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x='city-mpg', y='price', data=df)
plt.ylim(0,)
# Out:
# (0.0, 48263.54548143233)

# %%
df[['peak-rpm', 'highway-100km', 'price']].corr()
# Out:
#                peak-rpm  highway-100km  highway-100km     price
# peak-rpm       1.000000      -0.059326       0.018183 -0.101519
# highway-100km -0.059326       1.000000      -0.951133 -0.705115
# highway-100km  0.018183      -0.951133       1.000000  0.801313
# price         -0.101519      -0.705115       0.801313  1.000000

# %%
Yhat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))

ax1 = sns.distplot(df['price'], hist=False, color='r', label='Actual Value')
sns.distplot(Yhat, hist=False, color='b', label='Fitted Value', ax=ax1)

plt.title("Actual vs Fitted Value")
plt.xlabel("Price (in Dollar)")
plt.ylabel("Proportion of Cars")

plt.show()
plt.close()
# Out:
# d:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# d:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
def PlotPolly(model, independent_variable, dependent_variable, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)
    
    plt.plot(independent_variable, dependent_variable, "-", x_new, y_new,"-")
    plt.title("Polinomial with Matplotlb for Price")
    
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel("Price Of Car")
    
    plt.show()
    plt.close()

# %%
x = df["engine-size"]
y = df["price"]

# %%
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#            3         2
# -0.006655 x + 3.654 x - 434.9 x + 2.216e+04

# %%
PlotPolly(p, x, y, "engine-size")

# %%
np.polyfit(x, y, 3)
# Out:
# array([-6.65463225e-03,  3.65353104e+00, -4.34862435e+02,  2.21614640e+04])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr = pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (200, 5)

# %%
Z_pr.shape
# Out:
# (200, 21)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input = [("scale", StandardScaler()), ("polynomial", PolynomialFeatures()), ("model", LinearRegression())]

# %%
pipe = Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures()),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z, y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures()),
#                 ('model', LinearRegression())])

# %%
ypipe = pipe.predict(Z)
ypipe[0:4]
# Out:
# array([12185.50214925, 18471.02456274,  9633.7677439 , 17118.02190478])

# %%
Input = [("scale", StandardScaler()), ("model", LinearRegression())]
pipe = Pipeline(Input)
pipe.fit(Z,y)

ypipe = pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13414.58672588, 18422.81674396, 10304.4436527 , 17021.16068186])

# %%
lm.fit(X,Y)
print("The R-Square", lm.score(X,Y))
# Out:
# The R-Square 0.7609714051425502

# %%
Yhat = lm.predict(X)
print("MSE", Yhat[0:4])
# Out:
# MSE [13729.63711709 17400.60417954 10225.53219385 14730.80995231]

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(df['price'], Yhat)
print("Mean Square Error Predict by Price : ", mse)
# Out:
# Mean Square Error Predict by Price :  15095957.759716928

# %%
lm.fit(Z, df['price'])
print("The R-Square Is : ", lm.score(Z, df['price']))
# Out:
# The R-Square Is :  0.8230641384766875

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print("The Mean Square Error of Price and predicted value using multifit", \
    mean_squared_error(df["price"], Y_predict_multifit))
# Out:
# The Mean Square Error of Price and predicted value using multifit 11174463.429063676

# %%
from sklearn.metrics import r2_score
r_squared = r2_score(y, p(x))
print("The R-Value Is : ", r_squared)
# Out:
# The R-Value Is :  0.7901936848058164

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 13250411.624525923

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
new_input = np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
yhat = lm.predict(new_input)
# Out:
# d:\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.plot(new_input, yhat)
plt.show()
